# %% [markdown]
# ## Scan Env with LiDAR (Generate Map)

# %% [markdown]
# <span style="color:orange;font-size: 20px;font-weight:light;"> Need parameter tuning for correct scanning process </span>

# %%
# gap between lidar's scanning positions
LIDAR_POS_GAP = 0.5
# stop generate new lidar path when detect obstacles
OBSTACLE_DETECTION_DISTANCE = 0.2

# lidar initial position (lidar will move only on xy plane, while z fixed)
x_pos = -1.0
y_pos = -3.5
z_pos = 0.1

# %%
import open3d as o3d
import mujoco,sys
import numpy as np
import matplotlib.pyplot as plt
import time
from utils import *
sys.path.append('../package/helper/')
sys.path.append('../package/mujoco_usage/')
from mujoco_parser import *
from transformation import *
from slider import *
from utility import *

np.set_printoptions(precision=2,suppress=True,linewidth=100)
plt.rc('xtick',labelsize=6); plt.rc('ytick',labelsize=6)
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
print ("MuJoCo:[%s]"%(mujoco.__version__))

preprocessed_xml_name = "../xml/casa_scenes_transitional_1_site_v3_with_lidar.xml"
mujoco_env = MuJoCoParserClass(name='Tabletop',rel_xml_path=preprocessed_xml_name,verbose=True)

point_cloud = o3d.geometry.PointCloud()

print ("Done.")

render_HZ = 50
render_dt = 1./render_HZ
t_render = time.time()
t_render_prev = time.time()

# Reset
np.random.seed(seed=0)
mujoco_env.reset()

# Loop
mujoco_env.init_viewer(title='Lidar Auto-Scan',
                transparent=False,distance=3.0)

initial_point = [x_pos, y_pos, z_pos]
directions = np.array([[1, 0, 0], [-1, 0, 0], [0, 1, 0], [0, -1, 0]])
expanded_points = set()
expanded_points.add(tuple(initial_point))
current_points = {tuple(initial_point)}
mujoco_env.move_mocap(initial_point)

while mujoco_env.is_viewer_alive():
    contact_points = np.zeros((360, 3))
    start_time = time.time()
    while current_points:
        new_points = set()
        for point in current_points:
            expanded, point_cloud = expand_points(np.array(point), mujoco_env, render_HZ,LIDAR_POS_GAP, OBSTACLE_DETECTION_DISTANCE, directions, point_cloud, contact_points)
            new_points.update(expanded)
        current_points = new_points - expanded_points
        expanded_points.update(current_points)
        current_time = time.time()
        if current_time - start_time >= 1:
            print("expanded_points : ", len(expanded_points))
            start_time = current_time 
    mujoco_env.close_viewer()
    
# Results
lidar_positions = np.array(list(expanded_points))

import matplotlib.pyplot as plt
x = lidar_positions[:, 0]
y = lidar_positions[:, 1]
# Plot
plt.scatter(x, y, s=1)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('LiDAR Positions')
plt.grid(True)
plt.show()
# Out:
# objc[51817]: Class GLFWApplicationDelegate is implemented in both /opt/homebrew/anaconda3/envs/mujoco301Python310/lib/python3.10/site-packages/open3d/cpu/pybind.cpython-310-darwin.so (0x10f286e28) and /opt/homebrew/anaconda3/envs/mujoco301Python310/lib/python3.10/site-packages/glfw/libglfw.3.dylib (0x16e2ddbd0). One of the two will be used. Which one is undefined.
# objc[51817]: Class GLFWWindowDelegate is implemented in both /opt/homebrew/anaconda3/envs/mujoco301Python310/lib/python3.10/site-packages/open3d/cpu/pybind.cpython-310-darwin.so (0x10f286db0) and /opt/homebrew/anaconda3/envs/mujoco301Python310/lib/python3.10/site-packages/glfw/libglfw.3.dylib (0x16e2ddbf8). One of the two will be used. Which one is undefined.
# objc[51817]: Class GLFWContentView is implemented in both /opt/homebrew/anaconda3/envs/mujoco301Python310/lib/python3.10/site-packages/open3d/cpu/pybind.cpython-310-darwin.so (0x10f286e50) and /opt/homebrew/anaconda3/envs/mujoco301Python310/lib/python3.10/site-packages/glfw/libglfw.3.dylib (0x16e2ddc48). One of the two will be used. Which one is undefined.
# objc[51817]: Class GLFWWindow is implemented in both /opt/homebrew/anaconda3/envs/mujoco301Python310/lib/python3.10/site-packages/open3d/cpu/pybind.cpython-310-darwin.so (0x10f286ec8) and /opt/homebrew/anaconda3/envs/mujoco301Python310/lib/python3.10/site-packages/glfw/libglfw.3.dylib (0x16e2ddcc0). One of the two will be used. Which one is undefined.
# MuJoCo:[3.1.6]
# name:[Tabletop] dt:[0.002] HZ:[500]
# n_qpos:[85] n_qvel:[82] n_qacc:[82] n_ctrl:[0]
#
# n_body:[428]
#  [0/428] [world] mass:[0.00]kg
#  [1/428] [wall_back1_backing_outer_wall_backings_main] mass:[8864.64]kg
#  [2/428] [wall_back2_backing_outer_wall_backings_main] mass:[1736.64]kg
#  [3/428] [wall_front1_backing_outer_wall_backings_main] mass:[4782.24]kg
#  [4/428] [wall_front2_backing_outer_wall_backings_main] mass:[5754.24]kg
#  [5/428] [wall_left1_backing_outer_wall_backings_main] mass:[4847.04]kg
#  [6/428] [wall_left2_backing_outer_wall_backings_main] mass:[2643.84]kg
#  [7/428] [wall_right1_backing_outer_wall_backings_main] mass:[4587.84]kg
#  [8/428] [wall_right2_backing_outer_wall_backings_main] mass:[2643.84]kg
#  [9/428] [wall1_backing_inner_wall_backings_main] mass:[3291.84]kg
#  [10/428] [wall2_backing_inner_wall_backings_main] mass:[3291.84]kg
#  [11/428] [wall3_backing_inner_wall_backings_main] mass:[2643.84]kg
#  [12/428] [bedroom_door_backing_door_wall_backings_main] mass:[176.00]kg
#  [13/428] [restroom_door_backing_door_wall_backings_main] mass:[176.00]kg
#  [14/428] [childroom_door_backing_door_wall_backings_main] mass:[176.00]kg
#  [15/428] [wall1_backing_door_wall_backings_main] mass:[1023.84]kg
#  [16/428] [wall2_backing_door_wall_backings_main] mass:[1736.64]kg
#  [17/428] [wall3_backing_door_wall_backings_main] mass:[311.04]kg
#  [18/428] [wall4_backing_door_wall_backings_main] mass:[1347.84]kg
#  [19/428] [wall5_backing_door_wall_backings_main] mass:[537.84]kg
#  [20/428] [wall6_backing_door_wall_backings_main] mass:[537.84]kg
#  [21/428] [floor_kitchen_main] mass:[692.74]kg
#  [22/428] [floor_backing_kitchen_main] mass:[3463.68]kg
#  [23/428] [wall_kitchen_main] mass:[393.60]kg
#  [24/428] [wall_left_kitchen_main] mass:[609.60]kg
#  [25/428] [wall_right_kitchen_main] mass:[609.60]kg
#  [26/428] [outlet_kitchen_main] mass:[0.01]kg
#  [27/428] [outlet_2_kitchen_main] mass:[0.01]kg
#  [28/428] [outlet_3_kitchen_main] mass:[0.01]kg
#  [29/428] [untensil_rack_kitchen_main] mass:[8.41]kg
#  [30/428] [light_switch_kitchen_main] mass:[0.02]kg
#  [31/428] [light_switch_2_kitchen_main] mass:[0.02]kg
#  [32/428] [fridge_left_group_main] mass:[1414.95]kg
#  [33/428] [sink_left_group_main] mass:[49.56]kg
#  [34/428] [sink_left_group_spout] mass:[0.50]kg
#  [35/428] [sink_left_group_handle] mass:[0.08]kg
#  [36/428] [counter_left_group_main] mass:[0.64]kg
#  [37/428] [cab_1_left_group_main] mass:[0.74]kg
#  [38/428] [cab_1_left_group_hingeleftdoor] mass:[0.00]kg
#  [39/428] [cab_1_left_group_left_door_main] mass:[0.03]kg
#  [40/428] [cab_1_left_group_left_door_trims] mass:[0.04]kg
#  [41/428] [cab_1_left_group_left_door_handle_main] mass:[0.00]kg
#  [42/428] [cab_1_left_group_hingerightdoor] mass:[0.00]kg
#  [43/428] [cab_1_left_group_right_door_main] mass:[0.03]kg
#  [44/428] [cab_1_left_group_right_door_trims] mass:[0.04]kg
#  [45/428] [cab_1_left_group_right_door_handle_main] mass:[0.00]kg
#  [46/428] [cab_2_left_group_main] mass:[0.00]kg
#  [47/428] [cab_2_left_group_hingecab] mass:[0.00]kg
#  [48/428] [cab_2_left_group_shelf_0_main] mass:[0.10]kg
#  [49/428] [cab_2_left_group_shelf_1_main] mass:[0.10]kg
#  [50/428] [cab_3_left_group_main] mass:[0.74]kg
#  [51/428] [cab_3_left_group_hingeleftdoor] mass:[0.00]kg
#  [52/428] [cab_3_left_group_left_door_main] mass:[0.03]kg
#  [53/428] [cab_3_left_group_left_door_trims] mass:[0.04]kg
#  [54/428] [cab_3_left_group_left_door_handle_main] mass:[0.00]kg
#  [55/428] [cab_3_left_group_hingerightdoor] mass:[0.00]kg
#  [56/428] [cab_3_left_group_right_door_main] mass:[0.03]kg
#  [57/428] [cab_3_left_group_right_door_trims] mass:[0.04]kg
#  [58/428] [cab_3_left_group_right_door_handle_main] mass:[0.00]kg
#  [59/428] [stack_1_left_group_base_main] mass:[21.20]kg
#  [60/428] [stack_1_left_group_1_main] mass:[1.00]kg
#  [61/428] [stack_1_left_group_1_inner_box] mass:[0.80]kg
#  [62/428] [stack_1_left_group_1_door_main] mass:[0.00]kg
#  [63/428] [stack_1_left_group_1_door_trims] mass:[0.03]kg
#  [64/428] [stack_1_left_group_1_door_handle_main] mass:[0.00]kg
#  [65/428] [stack_1_left_group_2_main] mass:[1.00]kg
#  [66/428] [stack_1_left_group_2_inner_box] mass:[0.80]kg
#  [67/428] [stack_1_left_group_2_door_main] mass:[0.00]kg
#  [68/428] [stack_1_left_group_2_door_trims] mass:[0.03]kg
#  [69/428] [stack_1_left_group_2_door_handle_main] mass:[0.00]kg
#  [70/428] [stack_1_left_group_3_main] mass:[1.00]kg
#  [71/428] [stack_1_left_group_3_inner_box] mass:[0.80]kg
#  [72/428] [stack_1_left_group_3_door_main] mass:[0.00]kg
#  [73/428] [stack_1_left_group_3_door_trims] mass:[0.03]kg
#  [74/428] [stack_1_left_group_3_door_handle_main] mass:[0.00]kg
#  [75/428] [stack_1_left_group_4_main] mass:[1.00]kg
#  [76/428] [stack_1_left_group_4_inner_box] mass:[0.80]kg
#  [77/428] [stack_1_left_group_4_door_main] mass:[0.00]kg
#  [78/428] [stack_1_left_group_4_door_trims] mass:[0.03]kg
#  [79/428] [stack_1_left_group_4_door_handle_main] mass:[0.00]kg
#  [80/428] [stack_2_left_group_base_main] mass:[22.53]kg
#  [81/428] [stack_2_left_group_1_main] mass:[0.74]kg
#  [82/428] [stack_2_left_group_1_hingeleftdoor] mass:[0.00]kg
#  [83/428] [stack_2_left_group_1_left_door_main] mass:[0.01]kg
#  [84/428] [stack_2_left_group_1_left_door_trims] mass:[0.03]kg
#  [85/428] [stack_2_left_group_1_left_door_handle_main] mass:[0.00]kg
#  [86/428] [stack_2_left_group_1_hingerightdoor] mass:[0.00]kg
#  [87/428] [stack_2_left_group_1_right_door_main] mass:[0.01]kg
#  [88/428] [stack_2_left_group_1_right_door_trims] mass:[0.03]kg
#  [89/428] [stack_2_left_group_1_right_door_handle_main] mass:[0.00]kg
#  [90/428] [stack_2_left_group_2_main] mass:[1.00]kg
#  [91/428] [stack_2_left_group_2_inner_box] mass:[0.80]kg
#  [92/428] [stack_2_left_group_2_door_main] mass:[0.00]kg
#  [93/428] [stack_2_left_group_2_door_trims] mass:[0.02]kg
#  [94/428] [stack_2_left_group_2_door_handle_main] mass:[0.00]kg
#  [95/428] [stack_2_left_group_3_main] mass:[1.00]kg
#  [96/428] [stack_2_left_group_3_inner_box] mass:[0.80]kg
#  [97/428] [stack_2_left_group_3_door_main] mass:[0.00]kg
#  [98/428] [stack_2_left_group_3_door_trims] mass:[0.02]kg
#  [99/428] [stack_2_left_group_3_door_handle_main] mass:[0.00]kg
#  [100/428] [dishwasher_left_group_main] mass:[406.55]kg
#  [101/428] [stack_3_left_group_base_main] mass:[26.50]kg
#  [102/428] [stack_3_left_group_1_main] mass:[0.84]kg
#  [103/428] [stack_3_left_group_1_hingeleftdoor] mass:[0.00]kg
#  [104/428] [stack_3_left_group_1_left_door_main] mass:[0.02]kg
#  [105/428] [stack_3_left_group_1_left_door_trims] mass:[0.03]kg
#  [106/428] [stack_3_left_group_1_left_door_handle_main] mass:[0.00]kg
#  [107/428] [stack_3_left_group_1_hingerightdoor] mass:[0.00]kg
#  [108/428] [stack_3_left_group_1_right_door_main] mass:[0.02]kg
#  [109/428] [stack_3_left_group_1_right_door_trims] mass:[0.03]kg
#  [110/428] [stack_3_left_group_1_right_door_handle_main] mass:[0.00]kg
#  [111/428] [stack_3_left_group_2_main] mass:[0.00]kg
#  [112/428] [stack_3_left_group_2_door_main] mass:[0.00]kg
#  [113/428] [stack_3_left_group_2_door_trims] mass:[0.03]kg
#  [114/428] [stack_4_left_group_base_main] mass:[13.25]kg
#  [115/428] [stack_4_left_group_1_main] mass:[1.07]kg
#  [116/428] [stack_4_left_group_1_hingedoor] mass:[0.00]kg
#  [117/428] [stack_4_left_group_1_door_main] mass:[0.02]kg
#  [118/428] [stack_4_left_group_1_door_trims] mass:[0.03]kg
#  [119/428] [stack_4_left_group_1_door_handle_main] mass:[0.00]kg
#  [120/428] [stack_4_left_group_2_main] mass:[1.00]kg
#  [121/428] [stack_4_left_group_2_inner_box] mass:[0.80]kg
#  [122/428] [stack_4_left_group_2_door_main] mass:[0.00]kg
#  [123/428] [stack_4_left_group_2_door_trims] mass:[0.02]kg
#  [124/428] [stack_4_left_group_2_door_handle_main] mass:[0.00]kg
#  [125/428] [paper_towel_left_group_main] mass:[13.69]kg
#  [126/428] [counter_main_main_group_main] mass:[0.39]kg
#  [127/428] [stove_main_group_main] mass:[530.28]kg
#  [128/428] [stove_main_group_knob_rear_center] mass:[0.05]kg
#  [129/428] [stove_main_group_knob_rear_right] mass:[0.05]kg
#  [130/428] [stove_main_group_knob_front_left] mass:[0.05]kg
#  [131/428] [stove_main_group_knob_front_right] mass:[0.05]kg
#  [132/428] [stove_main_group_knob_rear_left] mass:[0.05]kg
#  [133/428] [counter_right_main_group_main] mass:[0.39]kg
#  [134/428] [cab_main_main_group_main] mass:[0.74]kg
#  [135/428] [cab_main_main_group_hingeleftdoor] mass:[0.00]kg
#  [136/428] [cab_main_main_group_left_door_main] mass:[0.03]kg
#  [137/428] [cab_main_main_group_left_door_trims] mass:[0.04]kg
#  [138/428] [cab_main_main_group_left_door_handle_main] mass:[0.00]kg
#  [139/428] [cab_main_main_group_hingerightdoor] mass:[0.00]kg
#  [140/428] [cab_main_main_group_right_door_main] mass:[0.03]kg
#  [141/428] [cab_main_main_group_right_door_trims] mass:[0.04]kg
#  [142/428] [cab_main_main_group_right_door_handle_main] mass:[0.00]kg
#  [143/428] [cab_1_main_group_main] mass:[0.74]kg
#  [144/428] [cab_1_main_group_hingeleftdoor] mass:[0.00]kg
#  [145/428] [cab_1_main_group_left_door_main] mass:[0.03]kg
#  [146/428] [cab_1_main_group_left_door_trims] mass:[0.04]kg
#  [147/428] [cab_1_main_group_left_door_handle_main] mass:[0.00]kg
#  [148/428] [cab_1_main_group_hingerightdoor] mass:[0.00]kg
#  [149/428] [cab_1_main_group_right_door_main] mass:[0.03]kg
#  [150/428] [cab_1_main_group_right_door_trims] mass:[0.04]kg
#  [151/428] [cab_1_main_group_right_door_handle_main] mass:[0.00]kg
#  [152/428] [microwave_main_group_main] mass:[110.67]kg
#  [153/428] [microwave_main_group_door] mass:[12.61]kg
#  [154/428] [cab_micro_main_group_main] mass:[0.42]kg
#  [155/428] [cab_micro_main_group_hingeleftdoor] mass:[0.00]kg
#  [156/428] [cab_micro_main_group_left_door_main] mass:[0.01]kg
#  [157/428] [cab_micro_main_group_left_door_trims] mass:[0.02]kg
#  [158/428] [cab_micro_main_group_left_door_handle_main] mass:[0.00]kg
#  [159/428] [cab_micro_main_group_hingerightdoor] mass:[0.00]kg
#  [160/428] [cab_micro_main_group_right_door_main] mass:[0.01]kg
#  [161/428] [cab_micro_main_group_right_door_trims] mass:[0.02]kg
#  [162/428] [cab_micro_main_group_right_door_handle_main] mass:[0.00]kg
#  [163/428] [cab_2_main_group_main] mass:[0.74]kg
#  [164/428] [cab_2_main_group_hingeleftdoor] mass:[0.00]kg
#  [165/428] [cab_2_main_group_left_door_main] mass:[0.03]kg
#  [166/428] [cab_2_main_group_left_door_trims] mass:[0.04]kg
#  [167/428] [cab_2_main_group_left_door_handle_main] mass:[0.00]kg
#  [168/428] [cab_2_main_group_hingerightdoor] mass:[0.00]kg
#  [169/428] [cab_2_main_group_right_door_main] mass:[0.03]kg
#  [170/428] [cab_2_main_group_right_door_trims] mass:[0.04]kg
#  [171/428] [cab_2_main_group_right_door_handle_main] mass:[0.00]kg
#  [172/428] [cab_3_main_group_main] mass:[0.74]kg
#  [173/428] [cab_3_main_group_hingeleftdoor] mass:[0.00]kg
#  [174/428] [cab_3_main_group_left_door_main] mass:[0.03]kg
#  [175/428] [cab_3_main_group_left_door_trims] mass:[0.04]kg
#  [176/428] [cab_3_main_group_left_door_handle_main] mass:[0.00]kg
#  [177/428] [cab_3_main_group_hingerightdoor] mass:[0.00]kg
#  [178/428] [cab_3_main_group_right_door_main] mass:[0.03]kg
#  [179/428] [cab_3_main_group_right_door_trims] mass:[0.04]kg
#  [180/428] [cab_3_main_group_right_door_handle_main] mass:[0.00]kg
#  [181/428] [stack_1_main_group_base_main] mass:[26.50]kg
#  [182/428] [stack_1_main_group_1_main] mass:[0.84]kg
#  [183/428] [stack_1_main_group_1_hingeleftdoor] mass:[0.00]kg
#  [184/428] [stack_1_main_group_1_left_door_main] mass:[0.02]kg
#  [185/428] [stack_1_main_group_1_left_door_trims] mass:[0.03]kg
#  [186/428] [stack_1_main_group_1_left_door_handle_main] mass:[0.00]kg
#  [187/428] [stack_1_main_group_1_hingerightdoor] mass:[0.00]kg
#  [188/428] [stack_1_main_group_1_right_door_main] mass:[0.02]kg
#  [189/428] [stack_1_main_group_1_right_door_trims] mass:[0.03]kg
#  [190/428] [stack_1_main_group_1_right_door_handle_main] mass:[0.00]kg
#  [191/428] [stack_1_main_group_2_main] mass:[1.00]kg
#  [192/428] [stack_1_main_group_2_inner_box] mass:[0.80]kg
#  [193/428] [stack_1_main_group_2_door_main] mass:[0.00]kg
#  [194/428] [stack_1_main_group_2_door_trims] mass:[0.02]kg
#  [195/428] [stack_1_main_group_2_door_handle_main] mass:[0.00]kg
#  [196/428] [stack_1_main_group_3_main] mass:[1.00]kg
#  [197/428] [stack_1_main_group_3_inner_box] mass:[0.80]kg
#  [198/428] [stack_1_main_group_3_door_main] mass:[0.00]kg
#  [199/428] [stack_1_main_group_3_door_trims] mass:[0.02]kg
#  [200/428] [stack_1_main_group_3_door_handle_main] mass:[0.00]kg
#  [201/428] [stack_2_main_group_base_main] mass:[26.50]kg
#  [202/428] [stack_2_main_group_1_main] mass:[1.00]kg
#  [203/428] [stack_2_main_group_1_inner_box] mass:[0.80]kg
#  [204/428] [stack_2_main_group_1_door_main] mass:[0.00]kg
#  [205/428] [stack_2_main_group_1_door_trims] mass:[0.03]kg
#  [206/428] [stack_2_main_group_1_door_handle_main] mass:[0.00]kg
#  [207/428] [stack_2_main_group_2_main] mass:[1.00]kg
#  [208/428] [stack_2_main_group_2_inner_box] mass:[0.80]kg
#  [209/428] [stack_2_main_group_2_door_main] mass:[0.00]kg
#  [210/428] [stack_2_main_group_2_door_trims] mass:[0.03]kg
#  [211/428] [stack_2_main_group_2_door_handle_main] mass:[0.00]kg
#  [212/428] [stack_2_main_group_3_main] mass:[1.00]kg
#  [213/428] [stack_2_main_group_3_inner_box] mass:[0.80]kg
#  [214/428] [stack_2_main_group_3_door_main] mass:[0.00]kg
#  [215/428] [stack_2_main_group_3_door_trims] mass:[0.03]kg
#  [216/428] [stack_2_main_group_3_door_handle_main] mass:[0.00]kg
#  [217/428] [stack_2_main_group_4_main] mass:[1.00]kg
#  [218/428] [stack_2_main_group_4_inner_box] mass:[0.80]kg
#  [219/428] [stack_2_main_group_4_door_main] mass:[0.00]kg
#  [220/428] [stack_2_main_group_4_door_trims] mass:[0.03]kg
#  [221/428] [stack_2_main_group_4_door_handle_main] mass:[0.00]kg
#  [222/428] [stack_3_main_group_base_main] mass:[26.50]kg
#  [223/428] [stack_3_main_group_1_main] mass:[0.84]kg
#  [224/428] [stack_3_main_group_1_hingeleftdoor] mass:[0.00]kg
#  [225/428] [stack_3_main_group_1_left_door_main] mass:[0.02]kg
#  [226/428] [stack_3_main_group_1_left_door_trims] mass:[0.03]kg
#  [227/428] [stack_3_main_group_1_left_door_handle_main] mass:[0.00]kg
#  [228/428] [stack_3_main_group_1_hingerightdoor] mass:[0.00]kg
#  [229/428] [stack_3_main_group_1_right_door_main] mass:[0.02]kg
#  [230/428] [stack_3_main_group_1_right_door_trims] mass:[0.03]kg
#  [231/428] [stack_3_main_group_1_right_door_handle_main] mass:[0.00]kg
#  [232/428] [stack_3_main_group_2_main] mass:[1.00]kg
#  [233/428] [stack_3_main_group_2_inner_box] mass:[0.80]kg
#  [234/428] [stack_3_main_group_2_door_main] mass:[0.00]kg
#  [235/428] [stack_3_main_group_2_door_trims] mass:[0.02]kg
#  [236/428] [stack_3_main_group_2_door_handle_main] mass:[0.00]kg
#  [237/428] [stack_3_main_group_3_main] mass:[1.00]kg
#  [238/428] [stack_3_main_group_3_inner_box] mass:[0.80]kg
#  [239/428] [stack_3_main_group_3_door_main] mass:[0.00]kg
#  [240/428] [stack_3_main_group_3_door_trims] mass:[0.02]kg
#  [241/428] [stack_3_main_group_3_door_handle_main] mass:[0.00]kg
#  [242/428] [stack_4_main_group_base_main] mass:[26.50]kg
#  [243/428] [stack_4_main_group_1_main] mass:[0.84]kg
#  [244/428] [stack_4_main_group_1_hingeleftdoor] mass:[0.00]kg
#  [245/428] [stack_4_main_group_1_left_door_main] mass:[0.02]kg
#  [246/428] [stack_4_main_group_1_left_door_trims] mass:[0.03]kg
#  [247/428] [stack_4_main_group_1_left_door_handle_main] mass:[0.00]kg
#  [248/428] [stack_4_main_group_1_hingerightdoor] mass:[0.00]kg
#  [249/428] [stack_4_main_group_1_right_door_main] mass:[0.02]kg
#  [250/428] [stack_4_main_group_1_right_door_trims] mass:[0.03]kg
#  [251/428] [stack_4_main_group_1_right_door_handle_main] mass:[0.00]kg
#  [252/428] [stack_4_main_group_2_main] mass:[1.00]kg
#  [253/428] [stack_4_main_group_2_inner_box] mass:[0.80]kg
#  [254/428] [stack_4_main_group_2_door_main] mass:[0.00]kg
#  [255/428] [stack_4_main_group_2_door_trims] mass:[0.02]kg
#  [256/428] [stack_4_main_group_2_door_handle_main] mass:[0.00]kg
#  [257/428] [stack_4_main_group_3_main] mass:[1.00]kg
#  [258/428] [stack_4_main_group_3_inner_box] mass:[0.80]kg
#  [259/428] [stack_4_main_group_3_door_main] mass:[0.00]kg
#  [260/428] [stack_4_main_group_3_door_trims] mass:[0.02]kg
#  [261/428] [stack_4_main_group_3_door_handle_main] mass:[0.00]kg
#  [262/428] [coffee_machine_main_group_main] mass:[12.29]kg
#  [263/428] [utensil_holder_main_group_main] mass:[10.17]kg
#  [264/428] [toaster_main_group_main] mass:[10.41]kg
#  [265/428] [knife_block_main_group_main] mass:[10.96]kg
#  [266/428] [floor_livingroom_main] mass:[1438.66]kg
#  [267/428] [floor_backing_livingroom_main] mass:[7193.28]kg
#  [268/428] [wall_livingroom_main] mass:[609.60]kg
#  [269/428] [wall_left_livingroom_main] mass:[849.60]kg
#  [270/428] [wall_front_livingroom_main] mass:[609.60]kg
#  [271/428] [wall_right_livingroom_main] mass:[633.60]kg
#  [272/428] [window_group_livingroom_left_root] mass:[0.00]kg
#  [273/428] [window_group_livingroom_left_trim_left_0_main] mass:[1.62]kg
#  [274/428] [window_group_livingroom_left_trim_right_0_main] mass:[1.62]kg
#  [275/428] [window_group_livingroom_left_trim_top_0_main] mass:[0.66]kg
#  [276/428] [window_group_livingroom_left_trim_bottom_0_main] mass:[0.66]kg
#  [277/428] [window_group_livingroom_left_vert_trim_0_main] mass:[0.81]kg
#  [278/428] [window_group_livingroom_left_horiz_trim_0_main] mass:[0.33]kg
#  [279/428] [window_group_livingroom_left_trim_left_1_main] mass:[1.62]kg
#  [280/428] [window_group_livingroom_left_trim_right_1_main] mass:[1.62]kg
#  [281/428] [window_group_livingroom_left_trim_top_1_main] mass:[0.66]kg
#  [282/428] [window_group_livingroom_left_trim_bottom_1_main] mass:[0.66]kg
#  [283/428] [window_group_livingroom_left_vert_trim_1_main] mass:[0.81]kg
#  [284/428] [window_group_livingroom_left_horiz_trim_1_main] mass:[0.33]kg
#  [285/428] [window_group_livingroom_left_trim_left_2_main] mass:[1.62]kg
#  [286/428] [window_group_livingroom_left_trim_right_2_main] mass:[1.62]kg
#  [287/428] [window_group_livingroom_left_trim_top_2_main] mass:[0.66]kg
#  [288/428] [window_group_livingroom_left_trim_bottom_2_main] mass:[0.66]kg
#  [289/428] [window_group_livingroom_left_vert_trim_2_main] mass:[0.81]kg
#  [290/428] [window_group_livingroom_left_horiz_trim_2_main] mass:[0.33]kg
#  [291/428] [window_group_livingroom_left_trim_left_3_main] mass:[1.62]kg
#  [292/428] [window_group_livingroom_left_trim_right_3_main] mass:[1.62]kg
#  [293/428] [window_group_livingroom_left_trim_top_3_main] mass:[0.66]kg
#  [294/428] [window_group_livingroom_left_trim_bottom_3_main] mass:[0.66]kg
#  [295/428] [window_group_livingroom_left_vert_trim_3_main] mass:[0.81]kg
#  [296/428] [window_group_livingroom_left_horiz_trim_3_main] mass:[0.33]kg
#  [297/428] [window_group_livingroom_left_door_main] mass:[33.08]kg
#  [298/428] [window_group_livingroom_left_frame_top_main] mass:[3.12]kg
#  [299/428] [window_group_livingroom_left_frame_bot_main] mass:[3.12]kg
#  [300/428] [window_group_livingroom_left_frame_right_main] mass:[1.69]kg
#  [301/428] [window_group_livingroom_left_frame_left_main] mass:[1.69]kg
#  [302/428] [table_livingroom_table_main] mass:[1.16]kg
#  [303/428] [tableleg1_livingroom_table_main] mass:[204.70]kg
#  [304/428] [tableleg2_livingroom_table_main] mass:[204.70]kg
#  [305/428] [stool_1_livingroom_table_main] mass:[159.13]kg
#  [306/428] [stool_2_livingroom_table_main] mass:[159.13]kg
#  [307/428] [stool_3_livingroom_table_main] mass:[159.13]kg
#  [308/428] [floor_hallway_main] mass:[688.90]kg
#  [309/428] [floor_backing_hallway_main] mass:[3444.48]kg
#  [310/428] [wall_front1_hallway_main] mass:[285.60]kg
#  [311/428] [wall_front2_hallway_main] mass:[57.60]kg
#  [312/428] [wall_front3_hallway_main] mass:[35.20]kg
#  [313/428] [wall_front4_hallway_main] mass:[261.60]kg
#  [314/428] [wall_front5_hallway_main] mass:[99.60]kg
#  [315/428] [wall_front6_hallway_main] mass:[35.20]kg
#  [316/428] [wall_front7_hallway_main] mass:[399.60]kg
#  [317/428] [wall_back1_backing_hallway_main] mass:[189.60]kg
#  [318/428] [wall_back2_backing_hallway_main] mass:[35.20]kg
#  [319/428] [wall_back3_backing_hallway_main] mass:[321.60]kg
#  [320/428] [floor_bedroom_main] mass:[1032.26]kg
#  [321/428] [floor_backing_bedroom_main] mass:[5161.28]kg
#  [322/428] [wall_bedroom_main] mass:[609.60]kg
#  [323/428] [wall_right_bedroom_main] mass:[849.60]kg
#  [324/428] [wall_left_bedroom_main] mass:[609.60]kg
#  [325/428] [wall_front1_backing_bedroom_main] mass:[189.60]kg
#  [326/428] [wall_front2_backing_bedroom_main] mass:[35.20]kg
#  [327/428] [wall_front3_backing_bedroom_main] mass:[321.60]kg
#  [328/428] [floor_restroom_main] mass:[551.23]kg
#  [329/428] [floor_backing_restroom_main] mass:[2839.68]kg
#  [330/428] [wall_left_restroom_main] mass:[489.60]kg
#  [331/428] [wall_right_restroom_main] mass:[489.60]kg
#  [332/428] [wall_front_restroom_main] mass:[417.60]kg
#  [333/428] [wall_back1_restroom_main] mass:[57.60]kg
#  [334/428] [wall_back2_restroom_main] mass:[35.20]kg
#  [335/428] [wall_back3_restroom_main] mass:[261.60]kg
#  [336/428] [floor_childroom_main] mass:[816.00]kg
#  [337/428] [floor_backing_childroom_main] mass:[4145.28]kg
#  [338/428] [wall_front_childroom_main] mass:[609.60]kg
#  [339/428] [wall_right_childroom_main] mass:[477.60]kg
#  [340/428] [wall_left_childroom_main] mass:[489.60]kg
#  [341/428] [wall_back1_childroom_main] mass:[99.60]kg
#  [342/428] [wall_back2_childroom_main] mass:[35.20]kg
#  [343/428] [wall_back3_childroom_main] mass:[399.60]kg
#  [344/428] [spray] mass:[0.13]kg
#  [345/428] [jug] mass:[0.25]kg
#  [346/428] [spoon] mass:[0.00]kg
#  [347/428] [site_bedroom] mass:[0.80]kg
#  [348/428] [site_kitchen] mass:[0.80]kg
#  [349/428] [site_livingroom] mass:[0.80]kg
#  [350/428] [site_childroom] mass:[0.80]kg
#  [351/428] [stack_1_hinge_bedroom] mass:[0.00]kg
#  [352/428] [stack_1_hinge_bedroom_main_group_base_main] mass:[26.50]kg
#  [353/428] [stack_1_hinge_bedroom_main_group_1_main] mass:[1.71]kg
#  [354/428] [stack_1_hinge_bedroom_main_group_1_hingeleftdoor] mass:[0.00]kg
#  [355/428] [stack_1_hinge_bedroom_main_group_1_left_door_main] mass:[0.06]kg
#  [356/428] [stack_1_hinge_bedroom_main_group_1_left_door_trims] mass:[0.08]kg
#  [357/428] [stack_1_hinge_bedroom_main_group_1_left_door_handle_main] mass:[0.00]kg
#  [358/428] [stack_1_hinge_bedroom_main_group_1_hingerightdoor] mass:[0.00]kg
#  [359/428] [stack_1_hinge_bedroom_main_group_1_right_door_main] mass:[0.06]kg
#  [360/428] [stack_1_hinge_bedroom_main_group_1_right_door_trims] mass:[0.08]kg
#  [361/428] [stack_1_hinge_bedroom_main_group_1_right_door_handle_main] mass:[0.00]kg
#  [362/428] [stack_2_hinge_bedroom] mass:[0.00]kg
#  [363/428] [stack_2_hinge_bedroom_main_group_base_main] mass:[26.50]kg
#  [364/428] [stack_2_hinge_bedroom_main_group_1_main] mass:[1.71]kg
#  [365/428] [stack_2_hinge_bedroom_main_group_1_hingeleftdoor] mass:[0.00]kg
#  [366/428] [stack_2_hinge_bedroom_main_group_1_left_door_main] mass:[0.06]kg
#  [367/428] [stack_2_hinge_bedroom_main_group_1_left_door_trims] mass:[0.08]kg
#  [368/428] [stack_2_hinge_bedroom_main_group_1_left_door_handle_main] mass:[0.00]kg
#  [369/428] [stack_2_hinge_bedroom_main_group_1_hingerightdoor] mass:[0.00]kg
#  [370/428] [stack_2_hinge_bedroom_main_group_1_right_door_main] mass:[0.06]kg
#  [371/428] [stack_2_hinge_bedroom_main_group_1_right_door_trims] mass:[0.08]kg
#  [372/428] [stack_2_hinge_bedroom_main_group_1_right_door_handle_main] mass:[0.00]kg
#  [373/428] [stack_3_hinge_bedroom] mass:[0.00]kg
#  [374/428] [stack_3_hinge_bedroom_main_group_base_main] mass:[26.50]kg
#  [375/428] [stack_3_hinge_bedroom_main_group_1_main] mass:[1.71]kg
#  [376/428] [stack_3_hinge_bedroom_main_group_1_hingeleftdoor] mass:[0.00]kg
#  [377/428] [stack_3_hinge_bedroom_main_group_1_left_door_main] mass:[0.06]kg
#  [378/428] [stack_3_hinge_bedroom_main_group_1_left_door_trims] mass:[0.08]kg
#  [379/428] [stack_3_hinge_bedroom_main_group_1_left_door_handle_main] mass:[0.00]kg
#  [380/428] [stack_3_hinge_bedroom_main_group_1_hingerightdoor] mass:[0.00]kg
#  [381/428] [stack_3_hinge_bedroom_main_group_1_right_door_main] mass:[0.06]kg
#  [382/428] [stack_3_hinge_bedroom_main_group_1_right_door_trims] mass:[0.08]kg
#  [383/428] [stack_3_hinge_bedroom_main_group_1_right_door_handle_main] mass:[0.00]kg
#  [384/428] [stack_2_bedroom] mass:[0.00]kg
#  [385/428] [stack_2_bedroom_group_base_main] mass:[26.50]kg
#  [386/428] [stack_2_bedroom_group_1_main] mass:[1.00]kg
#  [387/428] [stack_2_bedroom_group_1_inner_box] mass:[0.80]kg
#  [388/428] [stack_2_bedroom_group_1_door_main] mass:[0.00]kg
#  [389/428] [stack_2_bedroom_group_1_door_trims] mass:[0.03]kg
#  [390/428] [stack_2_bedroom_group_1_door_handle_main] mass:[0.00]kg
#  [391/428] [stack_2_bedroom_group_2_main] mass:[1.00]kg
#  [392/428] [stack_2_bedroom_group_2_inner_box] mass:[0.80]kg
#  [393/428] [stack_2_bedroom_group_2_door_main] mass:[0.00]kg
#  [394/428] [stack_2_bedroom_group_2_door_trims] mass:[0.03]kg
#  [395/428] [stack_2_bedroom_group_2_door_handle_main] mass:[0.00]kg
#  [396/428] [stack_2_bedroom_group_3_main] mass:[1.00]kg
#  [397/428] [stack_2_bedroom_group_3_inner_box] mass:[0.80]kg
#  [398/428] [stack_2_bedroom_group_3_door_main] mass:[0.00]kg
#  [399/428] [stack_2_bedroom_group_3_door_trims] mass:[0.03]kg
#  [400/428] [stack_2_bedroom_group_3_door_handle_main] mass:[0.00]kg
#  [401/428] [stack_1_hinge_childroom] mass:[0.00]kg
#  [402/428] [stack_1_hinge_childroom_main_group_base_main] mass:[26.50]kg
#  [403/428] [stack_1_hinge_childroom_main_group_1_main] mass:[1.71]kg
#  [404/428] [stack_1_hinge_childroom_main_group_1_hingeleftdoor] mass:[0.00]kg
#  [405/428] [stack_1_hinge_childroom_main_group_1_left_door_main] mass:[0.06]kg
#  [406/428] [stack_1_hinge_childroom_main_group_1_left_door_trims] mass:[0.08]kg
#  [407/428] [stack_1_hinge_childroom_main_group_1_left_door_handle_main] mass:[0.00]kg
#  [408/428] [stack_1_hinge_childroom_main_group_1_hingerightdoor] mass:[0.00]kg
#  [409/428] [stack_1_hinge_childroom_main_group_1_right_door_main] mass:[0.06]kg
#  [410/428] [stack_1_hinge_childroom_main_group_1_right_door_trims] mass:[0.08]kg
#  [411/428] [stack_1_hinge_childroom_main_group_1_right_door_handle_main] mass:[0.00]kg
#  [412/428] [cab_1_bathroom_hinge_group_main] mass:[0.74]kg
#  [413/428] [cab_1_bathroom_hinge_group_hingeleftdoor] mass:[0.00]kg
#  [414/428] [cab_1_bathroom_hinge_group_left_door_main] mass:[0.03]kg
#  [415/428] [cab_1_bathroom_hinge_group_left_door_trims] mass:[0.04]kg
#  [416/428] [cab_1_bathroom_hinge_group_left_door_handle_main] mass:[0.00]kg
#  [417/428] [cab_1_bathroom_hinge_group_hingerightdoor] mass:[0.00]kg
#  [418/428] [cab_1_bathroom_hinge_group_right_door_main] mass:[0.03]kg
#  [419/428] [cab_1_bathroom_hinge_group_right_door_trims] mass:[0.04]kg
#  [420/428] [cab_1_bathroom_hinge_group_right_door_handle_main] mass:[0.00]kg
#  [421/428] [resized0_013_Full_Size_Bed_with_White_Sheets_Black_V1] mass:[14822.17]kg
#  [422/428] [child_bunk_bed_normal_fixed] mass:[19504.68]kg
#  [423/428] [study_desk_v3_z_up] mass:[11311.06]kg
#  [424/428] [bathtub_v5] mass:[2680.06]kg
#  [425/428] [toilet_v2] mass:[999.17]kg
#  [426/428] [sink_with_faucet_selections_v3] mass:[399.06]kg
#  [427/428] [lidar] mass:[0.24]kg
# body_total_mass:[148737.31]kg
#
# n_geom:[1987]
# geom_names:['wall_back1_backing_outer_wall_backings_g0', 'wall_back1_backing_outer_wall_backings_g0_vis', 'wall_back2_backing_outer_wall_backings_g0', 'wall_back2_backing_outer_wall_backings_g0_vis', 'wall_front1_backing_outer_wall_backings_g0', 'wall_front1_backing_outer_wall_backings_g0_vis', 'wall_front2_backing_outer_wall_backings_g0', 'wall_front2_backing_outer_wall_backings_g0_vis', 'wall_left1_backing_outer_wall_backings_g0', 'wall_left1_backing_outer_wall_backings_g0_vis', 'wall_left2_backing_outer_wall_backings_g0', 'wall_left2_backing_outer_wall_backings_g0_vis', 'wall_right1_backing_outer_wall_backings_g0', 'wall_right1_backing_outer_wall_backings_g0_vis', 'wall_right2_backing_outer_wall_backings_g0', 'wall_right2_backing_outer_wall_backings_g0_vis', 'wall1_backing_inner_wall_backings_g0', 'wall1_backing_inner_wall_backings_g0_vis', 'wall2_backing_inner_wall_backings_g0', 'wall2_backing_inner_wall_backings_g0_vis', 'wall3_backing_inner_wall_backings_g0', 'wall3_backing_inner_wall_backings_g0_vis', 'bedroom_door_backing_door_wall_backings_g0', 'bedroom_door_backing_door_wall_backings_g0_vis', 'restroom_door_backing_door_wall_backings_g0', 'restroom_door_backing_door_wall_backings_g0_vis', 'childroom_door_backing_door_wall_backings_g0', 'childroom_door_backing_door_wall_backings_g0_vis', 'wall1_backing_door_wall_backings_g0', 'wall1_backing_door_wall_backings_g0_vis', 'wall2_backing_door_wall_backings_g0', 'wall2_backing_door_wall_backings_g0_vis', 'wall3_backing_door_wall_backings_g0', 'wall3_backing_door_wall_backings_g0_vis', 'wall4_backing_door_wall_backings_g0', 'wall4_backing_door_wall_backings_g0_vis', 'wall5_backing_door_wall_backings_g0', 'wall5_backing_door_wall_backings_g0_vis', 'wall6_backing_door_wall_backings_g0', 'wall6_backing_door_wall_backings_g0_vis', 'floor_kitchen_g0', 'floor_kitchen_g0_vis', 'floor_backing_kitchen_g0', 'floor_backing_kitchen_g0_vis', 'wall_kitchen_g0', 'wall_kitchen_g0_vis', 'wall_left_kitchen_g0', 'wall_left_kitchen_g0_vis', 'wall_right_kitchen_g0', 'wall_right_kitchen_g0_vis', 'outlet_kitchen_g0', 'outlet_2_kitchen_g0', 'outlet_3_kitchen_g0', 'untensil_rack_kitchen_g0', 'untensil_rack_kitchen_g1', 'light_switch_kitchen_g0', 'light_switch_2_kitchen_g0', 'fridge_left_group_g0', 'fridge_left_group_g1', 'fridge_left_group_g2', 'fridge_left_group_g3', 'fridge_left_group_g4', 'sink_left_group_g0', 'sink_left_group_bottom', 'sink_left_group_g2', 'sink_left_group_g3', 'sink_left_group_g4', 'sink_left_group_g5', 'sink_left_group_g6', 'sink_left_group_g7', 'sink_left_group_g8', 'sink_left_group_g9', 'sink_left_group_spout_top', 'sink_left_group_g11', 'sink_left_group_g12', 'sink_left_group_g13', 'sink_left_group_handle_main', 'counter_left_group_base_right', 'counter_left_group_base_left', 'counter_left_group_base_back', 'counter_left_group_base_front', 'counter_left_group_base_right_visual', 'counter_left_group_base_left_visual', 'counter_left_group_base_back_visual', 'counter_left_group_base_front_visual', 'counter_left_group_top_left_visual', 'counter_left_group_top_left_0', 'counter_left_group_top_left_1', 'counter_left_group_top_left_2', 'counter_left_group_top_left_3', 'counter_left_group_top_left_4', 'counter_left_group_top_right_visual', 'counter_left_group_top_right_0', 'counter_left_group_top_right_1', 'counter_left_group_top_front_visual', 'counter_left_group_top_front_0', 'counter_left_group_top_front_1', 'counter_left_group_top_back_visual', 'counter_left_group_top_back_0', 'counter_left_group_top_back_1', 'cab_1_left_group_top', 'cab_1_left_group_bottom', 'cab_1_left_group_back', 'cab_1_left_group_right', 'cab_1_left_group_left', 'cab_1_left_group_shelf', 'cab_1_left_group_top_visual', 'cab_1_left_group_bottom_visual', 'cab_1_left_group_back_visual', 'cab_1_left_group_right_visual', 'cab_1_left_group_left_visual', 'cab_1_left_group_shelf_visual', 'cab_1_left_group_left_door_door', 'cab_1_left_group_left_door_door_visual', 'cab_1_left_group_left_door_trim_top', 'cab_1_left_g ...
#
# n_joint:[67]
#  [0/67] [sink_left_group_spout_joint] axis:[0. 0. 1.]
#  [1/67] [sink_left_group_handle_temp_joint] axis:[1. 0. 0.]
#  [2/67] [sink_left_group_handle_joint] axis:[0. 1. 0.]
#  [3/67] [cab_1_left_group_leftdoorhinge] axis:[0. 0. 1.]
#  [4/67] [cab_1_left_group_rightdoorhinge] axis:[0. 0. 1.]
#  [5/67] [cab_3_left_group_leftdoorhinge] axis:[0. 0. 1.]
#  [6/67] [cab_3_left_group_rightdoorhinge] axis:[0. 0. 1.]
#  [7/67] [stack_1_left_group_1_slidejoint] axis:[0. 1. 0.]
#  [8/67] [stack_1_left_group_2_slidejoint] axis:[0. 1. 0.]
#  [9/67] [stack_1_left_group_3_slidejoint] axis:[0. 1. 0.]
#  [10/67] [stack_1_left_group_4_slidejoint] axis:[0. 1. 0.]
#  [11/67] [stack_2_left_group_1_leftdoorhinge] axis:[0. 0. 1.]
#  [12/67] [stack_2_left_group_1_rightdoorhinge] axis:[0. 0. 1.]
#  [13/67] [stack_2_left_group_2_slidejoint] axis:[0. 1. 0.]
#  [14/67] [stack_2_left_group_3_slidejoint] axis:[0. 1. 0.]
#  [15/67] [stack_3_left_group_1_leftdoorhinge] axis:[0. 0. 1.]
#  [16/67] [stack_3_left_group_1_rightdoorhinge] axis:[0. 0. 1.]
#  [17/67] [stack_4_left_group_1_doorhinge] axis:[0. 0. 1.]
#  [18/67] [stack_4_left_group_2_slidejoint] axis:[0. 1. 0.]
#  [19/67] [stove_main_group_knob_rear_center_joint] axis:[0. 1. 0.]
#  [20/67] [stove_main_group_knob_rear_right_joint] axis:[0. 1. 0.]
#  [21/67] [stove_main_group_knob_front_left_joint] axis:[0. 1. 0.]
#  [22/67] [stove_main_group_knob_front_right_joint] axis:[0. 1. 0.]
#  [23/67] [stove_main_group_knob_rear_left_joint] axis:[0. 1. 0.]
#  [24/67] [cab_main_main_group_leftdoorhinge] axis:[0. 0. 1.]
#  [25/67] [cab_main_main_group_rightdoorhinge] axis:[0. 0. 1.]
#  [26/67] [cab_1_main_group_leftdoorhinge] axis:[0. 0. 1.]
#  [27/67] [cab_1_main_group_rightdoorhinge] axis:[0. 0. 1.]
#  [28/67] [microwave_main_group_microjoint] axis:[0. 0. 1.]
#  [29/67] [cab_micro_main_group_leftdoorhinge] axis:[0. 0. 1.]
#  [30/67] [cab_micro_main_group_rightdoorhinge] axis:[0. 0. 1.]
#  [31/67] [cab_2_main_group_leftdoorhinge] axis:[0. 0. 1.]
#  [32/67] [cab_2_main_group_rightdoorhinge] axis:[0. 0. 1.]
#  [33/67] [cab_3_main_group_leftdoorhinge] axis:[0. 0. 1.]
#  [34/67] [cab_3_main_group_rightdoorhinge] axis:[0. 0. 1.]
#  [35/67] [stack_1_main_group_1_leftdoorhinge] axis:[0. 0. 1.]
#  [36/67] [stack_1_main_group_1_rightdoorhinge] axis:[0. 0. 1.]
#  [37/67] [stack_1_main_group_2_slidejoint] axis:[0. 1. 0.]
#  [38/67] [stack_1_main_group_3_slidejoint] axis:[0. 1. 0.]
#  [39/67] [stack_2_main_group_1_slidejoint] axis:[0. 1. 0.]
#  [40/67] [stack_2_main_group_2_slidejoint] axis:[0. 1. 0.]
#  [41/67] [stack_2_main_group_3_slidejoint] axis:[0. 1. 0.]
#  [42/67] [stack_2_main_group_4_slidejoint] axis:[0. 1. 0.]
#  [43/67] [stack_3_main_group_1_leftdoorhinge] axis:[0. 0. 1.]
#  [44/67] [stack_3_main_group_1_rightdoorhinge] axis:[0. 0. 1.]
#  [45/67] [stack_3_main_group_2_slidejoint] axis:[0. 1. 0.]
#  [46/67] [stack_3_main_group_3_slidejoint] axis:[0. 1. 0.]
#  [47/67] [stack_4_main_group_1_leftdoorhinge] axis:[0. 0. 1.]
#  [48/67] [stack_4_main_group_1_rightdoorhinge] axis:[0. 0. 1.]
#  [49/67] [stack_4_main_group_2_slidejoint] axis:[0. 1. 0.]
#  [50/67] [stack_4_main_group_3_slidejoint] axis:[0. 1. 0.]
#  [51/67] [obj_joint0] axis:[0. 0. 1.]
#  [52/67] [distr_counter_joint0] axis:[0. 0. 1.]
#  [53/67] [distr_cab_joint0] axis:[0. 0. 1.]
#  [54/67] [stack_1_hinge_bedroom_main_group_1_leftdoorhinge] axis:[0. 0. 1.]
#  [55/67] [stack_1_hinge_bedroom_main_group_1_rightdoorhinge] axis:[0. 0. 1.]
#  [56/67] [stack_2_hinge_bedroom_main_group_1_leftdoorhinge] axis:[0. 0. 1.]
#  [57/67] [stack_2_hinge_bedroom_main_group_1_rightdoorhinge] axis:[0. 0. 1.]
#  [58/67] [stack_3_hinge_bedroom_main_group_1_leftdoorhinge] axis:[0. 0. 1.]
#  [59/67] [stack_3_hinge_bedroom_main_group_1_rightdoorhinge] axis:[0. 0. 1.]
#  [60/67] [stack_2_bedroom_group_1_slidejoint] axis:[0. 1. 0.]
#  [61/67] [stack_2_bedroom_group_2_slidejoint] axis:[0. 1. 0.]
#  [62/67] [stack_2_bedroom_group_3_slidejoint] axis:[0. 1. 0.]
#  [63/67] [stack_1_hinge_childroom_main_group_1_leftdoorhinge] axis:[0. 0. 1.]
#  [64/67] [stack_1_hinge_childroom_main_group_1_rightdoorhinge] axis:[0. 0. 1.]
#  [65/67] [cab_1_bathroom_hinge_group_leftdoorhinge] axis:[0. 0. 1.]
#  [66/67] [cab_1_bathroom_hinge_group_rightdoorhinge] axis:[0. 0. 1.]
#
# n_dof:[82] (=number of rows of Jacobian)
#  [0/82] [None] attached joint:[sink_left_group_spout_joint] body:[sink_left_group_spout]
#  [1/82] [None] attached joint:[sink_left_group_handle_temp_joint] body:[sink_left_group_handle]
#  [2/82] [None] attached joint:[sink_left_group_handle_joint] body:[sink_left_group_handle]
#  [3/82] [None] attached joint:[cab_1_left_group_leftdoorhinge] body:[cab_1_left_group_hingeleftdoor]
#  [4/82] [None] attached joint:[cab_1_left_group_rightdoorhinge] body:[cab_1_left_group_hingerightdoor]
#  [5/82] [None] attached joint:[cab_3_left_group_leftdoorhinge] body:[cab_3_left_group_hingeleftdoor]
#  [6/82] [None] attached joint:[cab_3_left_group_rightdoorhinge] body:[cab_3_left_group_hingerightdoor]
#  [7/82] [None] attached joint:[stack_1_left_group_1_slidejoint] body:[stack_1_left_group_1_inner_box]
#  [8/82] [None] attached joint:[stack_1_left_group_2_slidejoint] body:[stack_1_left_group_2_inner_box]
#  [9/82] [None] attached joint:[stack_1_left_group_3_slidejoint] body:[stack_1_left_group_3_inner_box]
#  [10/82] [None] attached joint:[stack_1_left_group_4_slidejoint] body:[stack_1_left_group_4_inner_box]
#  [11/82] [None] attached joint:[stack_2_left_group_1_leftdoorhinge] body:[stack_2_left_group_1_hingeleftdoor]
#  [12/82] [None] attached joint:[stack_2_left_group_1_rightdoorhinge] body:[stack_2_left_group_1_hingerightdoor]
#  [13/82] [None] attached joint:[stack_2_left_group_2_slidejoint] body:[stack_2_left_group_2_inner_box]
#  [14/82] [None] attached joint:[stack_2_left_group_3_slidejoint] body:[stack_2_left_group_3_inner_box]
#  [15/82] [None] attached joint:[stack_3_left_group_1_leftdoorhinge] body:[stack_3_left_group_1_hingeleftdoor]
#  [16/82] [None] attached joint:[stack_3_left_group_1_rightdoorhinge] body:[stack_3_left_group_1_hingerightdoor]
#  [17/82] [None] attached joint:[stack_4_left_group_1_doorhinge] body:[stack_4_left_group_1_hingedoor]
#  [18/82] [None] attached joint:[stack_4_left_group_2_slidejoint] body:[stack_4_left_group_2_inner_box]
#  [19/82] [None] attached joint:[stove_main_group_knob_rear_center_joint] body:[stove_main_group_knob_rear_center]
#  [20/82] [None] attached joint:[stove_main_group_knob_rear_right_joint] body:[stove_main_group_knob_rear_right]
#  [21/82] [None] attached joint:[stove_main_group_knob_front_left_joint] body:[stove_main_group_knob_front_left]
#  [22/82] [None] attached joint:[stove_main_group_knob_front_right_joint] body:[stove_main_group_knob_front_right]
#  [23/82] [None] attached joint:[stove_main_group_knob_rear_left_joint] body:[stove_main_group_knob_rear_left]
#  [24/82] [None] attached joint:[cab_main_main_group_leftdoorhinge] body:[cab_main_main_group_hingeleftdoor]
#  [25/82] [None] attached joint:[cab_main_main_group_rightdoorhinge] body:[cab_main_main_group_hingerightdoor]
#  [26/82] [None] attached joint:[cab_1_main_group_leftdoorhinge] body:[cab_1_main_group_hingeleftdoor]
#  [27/82] [None] attached joint:[cab_1_main_group_rightdoorhinge] body:[cab_1_main_group_hingerightdoor]
#  [28/82] [None] attached joint:[microwave_main_group_microjoint] body:[microwave_main_group_door]
#  [29/82] [None] attached joint:[cab_micro_main_group_leftdoorhinge] body:[cab_micro_main_group_hingeleftdoor]
#  [30/82] [None] attached joint:[cab_micro_main_group_rightdoorhinge] body:[cab_micro_main_group_hingerightdoor]
#  [31/82] [None] attached joint:[cab_2_main_group_leftdoorhinge] body:[cab_2_main_group_hingeleftdoor]
#  [32/82] [None] attached joint:[cab_2_main_group_rightdoorhinge] body:[cab_2_main_group_hingerightdoor]
#  [33/82] [None] attached joint:[cab_3_main_group_leftdoorhinge] body:[cab_3_main_group_hingeleftdoor]
#  [34/82] [None] attached joint:[cab_3_main_group_rightdoorhinge] body:[cab_3_main_group_hingerightdoor]
#  [35/82] [None] attached joint:[stack_1_main_group_1_leftdoorhinge] body:[stack_1_main_group_1_hingeleftdoor]
#  [36/82] [None] attached joint:[stack_1_main_group_1_rightdoorhinge] body:[stack_1_main_group_1_hingerightdoor]
#  [37/82] [None] attached joint:[stack_1_main_group_2_slidejoint] body:[stack_1_main_group_2_inner_box]
#  [38/82] [None] attached joint:[stack_1_main_group_3_slidejoint] body:[stack_1_main_group_3_inner_box]
#  [39/82] [None] attached joint:[stack_2_main_group_1_slidejoint] body:[stack_2_main_group_1_inner_box]
#  [40/82] [None] attached joint:[stack_2_main_group_2_slidejoint] body:[stack_2_main_group_2_inner_box]
#  [41/82] [None] attached joint:[stack_2_main_group_3_slidejoint] body:[stack_2_main_group_3_inner_box]
#  [42/82] [None] attached joint:[stack_2_main_group_4_slidejoint] body:[stack_2_main_group_4_inner_box]
#  [43/82] [None] attached joint:[stack_3_main_group_1_leftdoorhinge] body:[stack_3_main_group_1_hingeleftdoor]
#  [44/82] [None] attached joint:[stack_3_main_group_1_rightdoorhinge] body:[stack_3_main_group_1_hingerightdoor]
#  [45/82] [None] attached joint:[stack_3_main_group_2_slidejoint] body:[stack_3_main_group_2_inner_box]
#  [46/82] [None] attached joint:[stack_3_main_group_3_slidejoint] body:[stack_3_main_group_3_inner_box]
#  [47/82] [None] attached joint:[stack_4_main_group_1_leftdoorhinge] body:[stack_4_main_group_1_hingeleftdoor]
#  [48/82] [None] attached joint:[stack_4_main_group_1_rightdoorhinge] body:[stack_4_main_group_1_hingerightdoor]
#  [49/82] [None] attached joint:[stack_4_main_group_2_slidejoint] body:[stack_4_main_group_2_inner_box]
#  [50/82] [None] attached joint:[stack_4_main_group_3_slidejoint] body:[stack_4_main_group_3_inner_box]
#  [51/82] [None] attached joint:[obj_joint0] body:[spray]
#  [52/82] [None] attached joint:[obj_joint0] body:[spray]
#  [53/82] [None] attached joint:[obj_joint0] body:[spray]
#  [54/82] [None] attached joint:[obj_joint0] body:[spray]
#  [55/82] [None] attached joint:[obj_joint0] body:[spray]
#  [56/82] [None] attached joint:[obj_joint0] body:[spray]
#  [57/82] [None] attached joint:[distr_counter_joint0] body:[jug]
#  [58/82] [None] attached joint:[distr_counter_joint0] body:[jug]
#  [59/82] [None] attached joint:[distr_counter_joint0] body:[jug]
#  [60/82] [None] attached joint:[distr_counter_joint0] body:[jug]
#  [61/82] [None] attached joint:[distr_counter_joint0] body:[jug]
#  [62/82] [None] attached joint:[distr_counter_joint0] body:[jug]
#  [63/82] [None] attached joint:[distr_cab_joint0] body:[spoon]
#  [64/82] [None] attached joint:[distr_cab_joint0] body:[spoon]
#  [65/82] [None] attached joint:[distr_cab_joint0] body:[spoon]
#  [66/82] [None] attached joint:[distr_cab_joint0] body:[spoon]
#  [67/82] [None] attached joint:[distr_cab_joint0] body:[spoon]
#  [68/82] [None] attached joint:[distr_cab_joint0] body:[spoon]
#  [69/82] [None] attached joint:[stack_1_hinge_bedroom_main_group_1_leftdoorhinge] body:[stack_1_hinge_bedroom_main_group_1_hingeleftdoor]
#  [70/82] [None] attached joint:[stack_1_hinge_bedroom_main_group_1_rightdoorhinge] body:[stack_1_hinge_bedroom_main_group_1_hingerightdoor]
#  [71/82] [None] attached joint:[stack_2_hinge_bedroom_main_group_1_leftdoorhinge] body:[stack_2_hinge_bedroom_main_group_1_hingeleftdoor]
#  [72/82] [None] attached joint:[stack_2_hinge_bedroom_main_group_1_rightdoorhinge] body:[stack_2_hinge_bedroom_main_group_1_hingerightdoor]
#  [73/82] [None] attached joint:[stack_3_hinge_bedroom_main_group_1_leftdoorhinge] body:[stack_3_hinge_bedroom_main_group_1_hingeleftdoor]
#  [74/82] [None] attached joint:[stack_3_hinge_bedroom_main_group_1_rightdoorhinge] body:[stack_3_hinge_bedroom_main_group_1_hingerightdoor]
#  [75/82] [None] attached joint:[stack_2_bedroom_group_1_slidejoint] body:[stack_2_bedroom_group_1_inner_box]
#  [76/82] [None] attached joint:[stack_2_bedroom_group_2_slidejoint] body:[stack_2_bedroom_group_2_inner_box]
#  [77/82] [None] attached joint:[stack_2_bedroom_group_3_slidejoint] body:[stack_2_bedroom_group_3_inner_box]
#  [78/82] [None] attached joint:[stack_1_hinge_childroom_main_group_1_leftdoorhinge] body:[stack_1_hinge_childroom_main_group_1_hingeleftdoor]
#  [79/82] [None] attached joint:[stack_1_hinge_childroom_main_group_1_rightdoorhinge] body:[stack_1_hinge_childroom_main_group_1_hingerightdoor]
#  [80/82] [None] attached joint:[cab_1_bathroom_hinge_group_leftdoorhinge] body:[cab_1_bathroom_hinge_group_hingeleftdoor]
#  [81/82] [None] attached joint:[cab_1_bathroom_hinge_group_rightdoorhinge] body:[cab_1_bathroom_hinge_group_hingerightdoor]
#
# Free joint information. n_free_joint:[3]
#  [0/3] [obj_joint0] body_name_attached:[spray]
#  [1/3] [distr_counter_joint0] body_name_attached:[jug]
#  [2/3] [distr_cab_joint0] body_name_attached:[spoon]
#
# Revolute joint information. n_rev_joint:[44]
#  [0/44] [sink_left_group_spout_joint] range:[-1.570]~[1.570]
#  [1/44] [sink_left_group_handle_temp_joint] range:[-0.785]~[0.785]
#  [2/44] [sink_left_group_handle_joint] range:[0.000]~[0.520]
#  [3/44] [cab_1_left_group_leftdoorhinge] range:[-3.000]~[0.000]
#  [4/44] [cab_1_left_group_rightdoorhinge] range:[0.000]~[3.000]
#  [5/44] [cab_3_left_group_leftdoorhinge] range:[-3.000]~[0.000]
#  [6/44] [cab_3_left_group_rightdoorhinge] range:[0.000]~[3.000]
#  [7/44] [stack_2_left_group_1_leftdoorhinge] range:[-3.000]~[0.000]
#  [8/44] [stack_2_left_group_1_rightdoorhinge] range:[0.000]~[3.000]
#  [9/44] [stack_3_left_group_1_leftdoorhinge] range:[-3.000]~[0.000]
#  [10/44] [stack_3_left_group_1_rightdoorhinge] range:[0.000]~[3.000]
#  [11/44] [stack_4_left_group_1_doorhinge] range:[0.000]~[3.000]
#  [12/44] [stove_main_group_knob_rear_center_joint] range:[0.000]~[0.000]
#  [13/44] [stove_main_group_knob_rear_right_joint] range:[0.000]~[0.000]
#  [14/44] [stove_main_group_knob_front_left_joint] range:[0.000]~[0.000]
#  [15/44] [stove_main_group_knob_front_right_joint] range:[0.000]~[0.000]
#  [16/44] [stove_main_group_knob_rear_left_joint] range:[0.000]~[0.000]
#  [17/44] [cab_main_main_group_leftdoorhinge] range:[-3.000]~[0.000]
#  [18/44] [cab_main_main_group_rightdoorhinge] range:[0.000]~[3.000]
#  [19/44] [cab_1_main_group_leftdoorhinge] range:[-3.000]~[0.000]
#  [20/44] [cab_1_main_group_rightdoorhinge] range:[0.000]~[3.000]
#  [21/44] [microwave_main_group_microjoint] range:[-90.000]~[0.000]
#  [22/44] [cab_micro_main_group_leftdoorhinge] range:[-3.000]~[0.000]
#  [23/44] [cab_micro_main_group_rightdoorhinge] range:[0.000]~[3.000]
#  [24/44] [cab_2_main_group_leftdoorhinge] range:[-3.000]~[0.000]
#  [25/44] [cab_2_main_group_rightdoorhinge] range:[0.000]~[3.000]
#  [26/44] [cab_3_main_group_leftdoorhinge] range:[-3.000]~[0.000]
#  [27/44] [cab_3_main_group_rightdoorhinge] range:[0.000]~[3.000]
#  [28/44] [stack_1_main_group_1_leftdoorhinge] range:[-3.000]~[0.000]
#  [29/44] [stack_1_main_group_1_rightdoorhinge] range:[0.000]~[3.000]
#  [30/44] [stack_3_main_group_1_leftdoorhinge] range:[-3.000]~[0.000]
#  [31/44] [stack_3_main_group_1_rightdoorhinge] range:[0.000]~[3.000]
#  [32/44] [stack_4_main_group_1_leftdoorhinge] range:[-3.000]~[0.000]
#  [33/44] [stack_4_main_group_1_rightdoorhinge] range:[0.000]~[3.000]
#  [34/44] [stack_1_hinge_bedroom_main_group_1_leftdoorhinge] range:[-3.000]~[0.000]
#  [35/44] [stack_1_hinge_bedroom_main_group_1_rightdoorhinge] range:[0.000]~[3.000]
#  [36/44] [stack_2_hinge_bedroom_main_group_1_leftdoorhinge] range:[-3.000]~[0.000]
#  [37/44] [stack_2_hinge_bedroom_main_group_1_rightdoorhinge] range:[0.000]~[3.000]
#  [38/44] [stack_3_hinge_bedroom_main_group_1_leftdoorhinge] range:[-3.000]~[0.000]
#  [39/44] [stack_3_hinge_bedroom_main_group_1_rightdoorhinge] range:[0.000]~[3.000]
#  [40/44] [stack_1_hinge_childroom_main_group_1_leftdoorhinge] range:[-3.000]~[0.000]
#  [41/44] [stack_1_hinge_childroom_main_group_1_rightdoorhinge] range:[0.000]~[3.000]
#  [42/44] [cab_1_bathroom_hinge_group_leftdoorhinge] range:[-3.000]~[0.000]
#  [43/44] [cab_1_bathroom_hinge_group_rightdoorhinge] range:[0.000]~[3.000]
#
# Prismatic joint information. n_pri_joint:[20]
#  [0/20] [stack_1_left_group_1_slidejoint] range:[-0.600]~[0.000]
#  [1/20] [stack_1_left_group_2_slidejoint] range:[-0.600]~[0.000]
#  [2/20] [stack_1_left_group_3_slidejoint] range:[-0.600]~[0.000]
#  [3/20] [stack_1_left_group_4_slidejoint] range:[-0.600]~[0.000]
#  [4/20] [stack_2_left_group_2_slidejoint] range:[-0.600]~[0.000]
#  [5/20] [stack_2_left_group_3_slidejoint] range:[-0.600]~[0.000]
#  [6/20] [stack_4_left_group_2_slidejoint] range:[-0.600]~[0.000]
#  [7/20] [stack_1_main_group_2_slidejoint] range:[-0.600]~[0.000]
#  [8/20] [stack_1_main_group_3_slidejoint] range:[-0.600]~[0.000]
#  [9/20] [stack_2_main_group_1_slidejoint] range:[-0.600]~[0.000]
#  [10/20] [stack_2_main_group_2_slidejoint] range:[-0.600]~[0.000]
#  [11/20] [stack_2_main_group_3_slidejoint] range:[-0.600]~[0.000]
#  [12/20] [stack_2_main_group_4_slidejoint] range:[-0.600]~[0.000]
#  [13/20] [stack_3_main_group_2_slidejoint] range:[-0.600]~[0.000]
#  [14/20] [stack_3_main_group_3_slidejoint] range:[-0.600]~[0.000]
#  [15/20] [stack_4_main_group_2_slidejoint] range:[-0.600]~[0.000]
#  [16/20] [stack_4_main_group_3_slidejoint] range:[-0.600]~[0.000]
#  [17/20] [stack_2_bedroom_group_1_slidejoint] range:[-0.600]~[0.000]
#  [18/20] [stack_2_bedroom_group_2_slidejoint] range:[-0.600]~[0.000]
#  [19/20] [stack_2_bedroom_group_3_slidejoint] range:[-0.600]~[0.000]
#
# Control information. n_ctrl:[0]
#
# n_sensor:[360]
# sensor_names:['rangefinder_0', 'rangefinder_1', 'rangefinder_2', 'rangefinder_3', 'rangefinder_4', 'rangefinder_5', 'rangefinder_6', 'rangefinder_7', 'rangefinder_8', 'rangefinder_9', 'rangefinder_10', 'rangefinder_11', 'rangefinder_12', 'rangefinder_13', 'rangefinder_14', 'rangefinder_15', 'rangefinder_16', 'rangefinder_17', 'rangefinder_18', 'rangefinder_19', 'rangefinder_20', 'rangefinder_21', 'rangefinder_22', 'rangefinder_23', 'rangefinder_24', 'rangefinder_25', 'rangefinder_26', 'rangefinder_27', 'rangefinder_28', 'rangefinder_29', 'rangefinder_30', 'rangefinder_31', 'rangefinder_32', 'rangefinder_33', 'rangefinder_34', 'rangefinder_35', 'rangefinder_36', 'rangefinder_37', 'rangefinder_38', 'rangefinder_39', 'rangefinder_40', 'rangefinder_41', 'rangefinder_42', 'rangefinder_43', 'rangefinder_44', 'rangefinder_45', 'rangefinder_46', 'rangefinder_47', 'rangefinder_48', 'rangefinder_49', 'rangefinder_50', 'rangefinder_51', 'rangefinder_52', 'rangefinder_53', 'rangefinder_54', 'rangefinder_55', 'rangefinder_56', 'rangefinder_57', 'rangefinder_58', 'rangefinder_59', 'rangefinder_60', 'rangefinder_61', 'rangefinder_62', 'rangefinder_63', 'rangefinder_64', 'rangefinder_65', 'rangefinder_66', 'rangefinder_67', 'rangefinder_68', 'rangefinder_69', 'rangefinder_70', 'rangefinder_71', 'rangefinder_72', 'rangefinder_73', 'rangefinder_74', 'rangefinder_75', 'rangefinder_76', 'rangefinder_77', 'rangefinder_78', 'rangefinder_79', 'rangefinder_80', 'rangefinder_81', 'rangefinder_82', 'rangefinder_83', 'rangefinder_84', 'rangefinder_85', 'rangefinder_86', 'rangefinder_87', 'rangefinder_88', 'rangefinder_89', 'rangefinder_90', 'rangefinder_91', 'rangefinder_92', 'rangefinder_93', 'rangefinder_94', 'rangefinder_95', 'rangefinder_96', 'rangefinder_97', 'rangefinder_98', 'rangefinder_99', 'rangefinder_100', 'rangefinder_101', 'rangefinder_102', 'rangefinder_103', 'rangefinder_104', 'rangefinder_105', 'rangefinder_106', 'rangefinder_107', 'rangefinder_108', 'rangefinder_109', 'rangefinder_110', 'rangefinder_111', 'rangefinder_112', 'rangefinder_113', 'rangefinder_114', 'rangefinder_115', 'rangefinder_116', 'rangefinder_117', 'rangefinder_118', 'rangefinder_119', 'rangefinder_120', 'rangefinder_121', 'rangefinder_122', 'rangefinder_123', 'rangefinder_124', 'rangefinder_125', 'rangefinder_126', 'rangefinder_127', 'rangefinder_128', 'rangefinder_129', 'rangefinder_130', 'rangefinder_131', 'rangefinder_132', 'rangefinder_133', 'rangefinder_134', 'rangefinder_135', 'rangefinder_136', 'rangefinder_137', 'rangefinder_138', 'rangefinder_139', 'rangefinder_140', 'rangefinder_141', 'rangefinder_142', 'rangefinder_143', 'rangefinder_144', 'rangefinder_145', 'rangefinder_146', 'rangefinder_147', 'rangefinder_148', 'rangefinder_149', 'rangefinder_150', 'rangefinder_151', 'rangefinder_152', 'rangefinder_153', 'rangefinder_154', 'rangefinder_155', 'rangefinder_156', 'rangefinder_157', 'rangefinder_158', 'rangefinder_159', 'rangefinder_160', 'rangefinder_161', 'rangefinder_162', 'rangefinder_163', 'rangefinder_164', 'rangefinder_165', 'rangefinder_166', 'rangefinder_167', 'rangefinder_168', 'rangefinder_169', 'rangefinder_170', 'rangefinder_171', 'rangefinder_172', 'rangefinder_173', 'rangefinder_174', 'rangefinder_175', 'rangefinder_176', 'rangefinder_177', 'rangefinder_178', 'rangefinder_179', 'rangefinder_180', 'rangefinder_181', 'rangefinder_182', 'rangefinder_183', 'rangefinder_184', 'rangefinder_185', 'rangefinder_186', 'rangefinder_187', 'rangefinder_188', 'rangefinder_189', 'rangefinder_190', 'rangefinder_191', 'rangefinder_192', 'rangefinder_193', 'rangefinder_194', 'rangefinder_195', 'rangefinder_196', 'rangefinder_197', 'rangefinder_198', 'rangefinder_199', 'rangefinder_200', 'rangefinder_201', 'rangefinder_202', 'rangefinder_203', 'rangefinder_204', 'rangefinder_205', 'rangefinder_206', 'rangefinder_207', 'rangefinder_208', 'rangefinder_209', 'rangefinder_210', 'rangefinder_211', 'rangefinder_212', 'rangefinder_213', 'rangefinder_214', 'rangefinde ...
# n_site:[1104]
# site_names:['wall_back1_backing_outer_wall_backings_default_site', 'wall_back2_backing_outer_wall_backings_default_site', 'wall_front1_backing_outer_wall_backings_default_site', 'wall_front2_backing_outer_wall_backings_default_site', 'wall_left1_backing_outer_wall_backings_default_site', 'wall_left2_backing_outer_wall_backings_default_site', 'wall_right1_backing_outer_wall_backings_default_site', 'wall_right2_backing_outer_wall_backings_default_site', 'wall1_backing_inner_wall_backings_default_site', 'wall2_backing_inner_wall_backings_default_site', 'wall3_backing_inner_wall_backings_default_site', 'bedroom_door_backing_door_wall_backings_default_site', 'restroom_door_backing_door_wall_backings_default_site', 'childroom_door_backing_door_wall_backings_default_site', 'wall1_backing_door_wall_backings_default_site', 'wall2_backing_door_wall_backings_default_site', 'wall3_backing_door_wall_backings_default_site', 'wall4_backing_door_wall_backings_default_site', 'wall5_backing_door_wall_backings_default_site', 'wall6_backing_door_wall_backings_default_site', 'floor_kitchen_default_site', 'floor_backing_kitchen_default_site', 'wall_kitchen_default_site', 'wall_left_kitchen_default_site', 'wall_right_kitchen_default_site', 'outlet_kitchen_default_site', 'outlet_2_kitchen_default_site', 'outlet_3_kitchen_default_site', 'untensil_rack_kitchen_default_site', 'light_switch_kitchen_default_site', 'light_switch_2_kitchen_default_site', 'fridge_left_group_default_site', 'sink_left_group_ext_p0', 'sink_left_group_ext_px', 'sink_left_group_ext_py', 'sink_left_group_ext_pz', 'sink_left_group_int_p0', 'sink_left_group_int_px', 'sink_left_group_int_py', 'sink_left_group_int_pz', 'sink_left_group_default_site', 'sink_left_group_water', 'counter_left_group_ext_p0', 'counter_left_group_ext_px', 'counter_left_group_ext_py', 'counter_left_group_ext_pz', 'counter_left_group_int_p0', 'counter_left_group_int_px', 'counter_left_group_int_py', 'counter_left_group_int_pz', 'counter_left_group_default_site', 'cab_1_left_group_ext_p0', 'cab_1_left_group_ext_px', 'cab_1_left_group_ext_py', 'cab_1_left_group_ext_pz', 'cab_1_left_group_int_p0', 'cab_1_left_group_int_px', 'cab_1_left_group_int_py', 'cab_1_left_group_int_pz', 'cab_1_left_group_default_site', 'cab_1_left_group_leftdoor_p1', 'cab_1_left_group_leftdoor_p2', 'cab_1_left_group_leftdoor_p3', 'cab_1_left_group_left_door_default_site', 'cab_1_left_group_left_door_handle_default_site', 'cab_1_left_group_rightdoor_p1', 'cab_1_left_group_rightdoor_p2', 'cab_1_left_group_rightdoor_p3', 'cab_1_left_group_right_door_default_site', 'cab_1_left_group_right_door_handle_default_site', 'cab_2_left_group_ext_p0', 'cab_2_left_group_ext_px', 'cab_2_left_group_ext_py', 'cab_2_left_group_ext_pz', 'cab_2_left_group_int_p0', 'cab_2_left_group_int_px', 'cab_2_left_group_int_py', 'cab_2_left_group_int_pz', 'cab_2_left_group_default_site', 'cab_2_left_group_shelf_0_default_site', 'cab_2_left_group_shelf_1_default_site', 'cab_3_left_group_ext_p0', 'cab_3_left_group_ext_px', 'cab_3_left_group_ext_py', 'cab_3_left_group_ext_pz', 'cab_3_left_group_int_p0', 'cab_3_left_group_int_px', 'cab_3_left_group_int_py', 'cab_3_left_group_int_pz', 'cab_3_left_group_default_site', 'cab_3_left_group_leftdoor_p1', 'cab_3_left_group_leftdoor_p2', 'cab_3_left_group_leftdoor_p3', 'cab_3_left_group_left_door_default_site', 'cab_3_left_group_left_door_handle_default_site', 'cab_3_left_group_rightdoor_p1', 'cab_3_left_group_rightdoor_p2', 'cab_3_left_group_rightdoor_p3', 'cab_3_left_group_right_door_default_site', 'cab_3_left_group_right_door_handle_default_site', 'stack_1_left_group_base_default_site', 'stack_1_left_group_1_ext_p0', 'stack_1_left_group_1_ext_px', 'stack_1_left_group_1_ext_py', 'stack_1_left_group_1_ext_pz', 'stack_1_left_group_1_default_site', 'stack_1_left_group_1_int_p0', 'stack_1_left_group_1_int_px', 'stack_1_left_group_1_int_py', 'stack_1_left_group_1_int_pz', 'stack_1_left_group_1_door_default_site', 'stack_1_left_group_1_do ...
# Done.
# expanded_points :  12
# expanded_points :  20
# expanded_points :  28
# expanded_points :  36
# expanded_points :  47
# expanded_points :  59
# expanded_points :  71
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 53
#      51 new_points = set()
#      52 for point in current_points:
# ---> 53     expanded, point_cloud = expand_points(np.array(point), mujoco_env, render_HZ,LIDAR_POS_GAP, OBSTACLE_DETECTION_DISTANCE, directions, point_cloud, contact_points)
#      54     new_points.update(expanded)
#      55 current_points = new_points - expanded_points
#
# File ~/RobotPlayGround/MuJoCo_AutoMapGenerator/code/utils.py:26, in expand_points(point, env, render_HZ, resolution, detection_distance, directions, point_cloud, contact_points)
#      24 env.move_mocap(new_point)
#      25 env.step(nstep=env.HZ//render_HZ)
# ---> 26 env.render()
#      28 is_empty = True
#      29 for sensor_idx in range(360):
#
# File ~/RobotPlayGround/MuJoCo_AutoMapGenerator/code/../package/mujoco_usage/mujoco_parser.py:414, in MuJoCoParserClass.render(self)
#     410 """
#     411     Render
#     412 """
#     413 if self.use_mujoco_viewer:
# --> 414     self.viewer.render()
#     415 else:
#     416     print ("[%s] Viewer NOT initialized."%(self.name))
#
# File ~/RobotPlayGround/MuJoCo_AutoMapGenerator/code/../package/mujoco_usage/mujoco_custom_viewer.py:608, in MujocoMinimalViewer.render(self)
#     606 def render(self):
#     607     if not self.is_alive:
# --> 608         raise Exception(
#     609             "GLFW window does not exist but you tried to render.")
#     610     if glfw.window_should_close(self.window):
#     611         self.close()
#
# Exception: GLFW window does not exist but you tried to render.

# %% [markdown]
# ### Save Point Cloud

# %%
from datetime import datetime
import os
now = datetime.now()
# pointcloud_name =preprocessed_xml_name.replace(".xml", "")
# pointcloud_name = preprocessed_xml_name.split('../xml/')[1]
pointcloud_name = preprocessed_xml_name.replace('../xml/','')
pointcloud_name = pointcloud_name.replace('.xml','')
pointcloud_name = pointcloud_name.replace("/", "_") + now.strftime("_%Y%m%d_%H%M%S") + ".ply"
pointcloud_file_path = "./point_cloud/" + pointcloud_name

directory = os.path.dirname(pointcloud_file_path)
if not os.path.exists(directory):
    os.makedirs(directory)
o3d.io.write_point_cloud(pointcloud_file_path, point_cloud)
# Out:
# True

# %%
import open3d as o3d

# Specify the file path
# file_path = pointcloud_file_path
file_path = './point_cloud/casa_scenes_transitional_1_site_v3_with_lidar_20241017_135342.ply'

# Load the point cloud data
loaded_point_cloud = o3d.io.read_point_cloud(file_path)

# Print some information about the loaded point cloud
print(f"Loaded point cloud with {len(loaded_point_cloud.points)} points")
def close_visualizer(vis):
    vis.destroy_window()

# Create a visualizer
vis = o3d.visualization.VisualizerWithKeyCallback()
vis.create_window()
vis.add_geometry(loaded_point_cloud)
vis.register_key_callback(ord('Q'), close_visualizer)
vis.register_key_callback(ord('q'), close_visualizer)
vis.run()
vis.destroy_window()
# Out:
# Loaded point cloud with 3821 points
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display
# [Open3D WARNING] GLFW Error: Cocoa: Failed to find service port for display

# %%
import matplotlib.pyplot as plt
import open3d as o3d

# Specify the file path
file_path = pointcloud_file_path

# Load the point cloud data
loaded_point_cloud = o3d.io.read_point_cloud(file_path)

points = loaded_point_cloud.points
# Separate X, Y (ignore Z)
x_vals = [point[0] for point in points]
y_vals = [point[1] for point in points]

# Plot the XY points in a scatter plot
plt.figure(figsize=(8, 8))
plt.scatter(x_vals, y_vals, s=1, c='b')  # s=1 for point size, c='b' for blue color
plt.title('2D Projection of Point Cloud (X, Y)')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
import open3d as o3d
import matplotlib.pyplot as plt
import math
# Specify the file path
# file_path = pointcloud_file_path
file_path = './point_cloud/casa_scenes_transitional_1_site_v3_with_lidar_20241017_135342.ply'

# Load the point cloud data
loaded_point_cloud = o3d.io.read_point_cloud(file_path)

points = loaded_point_cloud.points
# Separate X, Y (ignore Z)
x_vals = [point[0] for point in points]
y_vals = [point[1] for point in points]

# print("x_vals[0] : ", x_vals[0])
# print(min(x_vals))
# print(max(x_vals))
# print(min(y_vals))
# print(max(y_vals))
# print(math.ceil(max(x_vals)))
# print(math.floor(min(x_vals)))

def _get_round_value(value):
    if value > 0:
        return math.ceil(value)
    else:
        return math.floor(value)

def get_max_min_with_round(pos_arr):
    min_value = _get_round_value(min(pos_arr))
    max_value = _get_round_value(max(pos_arr))

    return [min_value, max_value]

def get_gridmap_size(x_arr, y_arr):
    gridmap_x_size = get_max_min_with_round(x_arr)
    gridmap_y_size = get_max_min_with_round(y_arr)

    print(gridmap_x_size)
    print(gridmap_y_size)

    return gridmap_x_size[1] - gridmap_x_size[0], gridmap_y_size[1] - gridmap_y_size[0]


# print(get_max_min_with_round(x_vals))
# print(get_max_min_with_round(y_vals))

# gridmap_size = [get_max_min_with_round(x_vals), get_max_min_with_round(y_vals)]
print(get_gridmap_size(x_vals,y_vals))

def generate_gridmap(gridmap_size, gridmap_resolution):
    x_size = gridmap_size[0] * gridmap_resolution
    y_size = gridmap_size[1] * gridmap_resolution
    
    
    return 


GRID_RESOLUTION = 100 # GRID_RESOLUTION * occupancy grid map(1 space) = mujoco (1.0)
NUM_OF_POINTS_THRESHOLD = 10
    
gridmap_size = get_gridmap_size(x_vals,y_vals)
gridmap = np.zeros((gridmap_size[0] * GRID_RESOLUTION, gridmap_size[1] * GRID_RESOLUTION))

print(np.shape(gridmap))

# print(gridmap_size)



# print(max(y_vals))
# ┏━━━━━┓
# ┃ x   ┃
# ┃ x   ┃
# ┗━━━━━┛
# if NUM_OF_POINTS_THRESHOLD = 2, result is 255
# if NUM_OF_POINTS_THRESHOLD = 4, result is 127
# 1. generate GRID MAP


# 2. update robot radius as
# Out:
# [-6, 11]
# [-12, 1]
# (17, 13)
# [-6, 11]
# [-12, 1]
# (1700, 1300)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# import open3d as o3d
# import numpy as np
# import matplotlib.pyplot as plt

# # Specify the file path
# file_path = pointcloud_file_path

# # Load the point cloud data
# loaded_point_cloud = o3d.io.read_point_cloud(pointcloud_file_path)

# # Get points as a numpy array (X, Y, Z)
# points = np.asarray(loaded_point_cloud.points)

# # Extract X, Y coordinates (2D projection)
# x_vals = points[:, 0]
# y_vals = points[:, 1]

# # Define the resolution of the output PGM image
# grid_size = 200  # Adjust based on your required resolution
# x_min, x_max = np.min(x_vals), np.max(x_vals)
# y_min, y_max = np.min(y_vals), np.max(y_vals)

# # Normalize the coordinates to fit into the grid
# x_normalized = ((x_vals - x_min) / (x_max - x_min) * (grid_size - 1)).astype(int)
# y_normalized = ((y_vals - y_min) / (y_max - y_min) * (grid_size - 1)).astype(int)

# # Create an empty grid for the PGM image
# pgm_image = np.zeros((grid_size, grid_size), dtype=np.uint8)

# # Fill the grid based on point density (you can adjust this logic)
# for x, y in zip(x_normalized, y_normalized):
#     pgm_image[y, x] += 1  # Increment the point count at this location

# # Normalize the image values to 0-255 for grayscale
# pgm_image = np.clip(pgm_image, 0, 255)

# # Save the result as a PGM file
# with open("output.pgm", "wb") as f:
#     f.write(b"P5\n%d %d\n255\n" % (grid_size, grid_size))
#     pgm_image.tofile(f)

# # Optionally, display the image using matplotlib
# plt.imshow(pgm_image, cmap="gray")
# plt.title("2D PGM Projection from Point Cloud")
# plt.show()
